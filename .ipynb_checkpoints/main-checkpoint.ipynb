# %%
#dependencies 
import pandas as pd

# %%
# import csv files
student_file = 'students_complete.csv'
schools_file = 'schools_complete.csv'

student_data_df = pd.DataFrame(pd.read_csv(student_file, encoding='iso-8859-1', low_memory=False))
school_data_df = pd.DataFrame(pd.read_csv(schools_file, encoding='iso-8859-1', low_memory=False))
school_data_df.head()
#school_data_df
# Out:
#    School ID                   name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
student_data_df.head()
# Out:
#    Student ID               name gender grade             school  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
#rename columns to allow for data to be merged

school_data_df.columns = ["School ID", "School Name", "type","size","budget"]
student_data_df.columns = ["Student ID", "Student Name", "gender","grade","School Name", "reading_score", "math_score"]

student_data_df.head()
# Out:
#    Student ID       Student Name gender grade        School Name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
#merge dfs 

merge_data = pd.merge(school_data_df, student_data_df, on="School Name")

merge_data.head()
# Out:
#    School ID        School Name      type  size   budget  Student ID  \
# 0          0  Huang High School  District  2917  1910635           0
# 1          0  Huang High School  District  2917  1910635           1
# 2          0  Huang High School  District  2917  1910635           2
# 3          0  Huang High School  District  2917  1910635           3
# 4          0  Huang High School  District  2917  1910635           4
#
#         Student Name gender grade  reading_score  math_score
# 0       Paul Bradley      M   9th             66          79
# 1       Victor Smith      M  12th             94          61
# 2    Kevin Rodriguez      M  12th             90          60
# 3  Dr. Richard Scott      M  12th             67          58
# 4         Bonnie Ray      F   9th             97          84

# %%
total_schools = len(merge_data["School Name"].unique())
total_schools
# Out:
# 15

# %%
total_students = len(merge_data["Student Name"].unique())
total_students
# Out:
# 32715

# %%
total_budget = sum(school_data_df["budget"])
total_budget
# Out:
# 24649428

# %%
average_math_score = merge_data["math_score"].mean()
average_math_score
# Out:
# 78.98537145774827

# %%
average_reading_score = merge_data["reading_score"].mean()
average_reading_score
# Out:
# 81.87784018381414

# %%
passing_math = merge_data.loc[merge_data["math_score"] > 64,:]
pct_pass_math = len(passing_math) / len(merge_data)
pct_pass_math
# Out:
# 0.8472810824610671

# %%
passing_read = merge_data.loc[merge_data["reading_score"] > 64,:]
pct_pass_read = len(passing_read) / len(merge_data)
pct_pass_read
# Out:
# 0.9619862139392392

# %%
overall_pass = (pct_pass_math + pct_pass_read) / 2
overall_pass
# Out:
# 0.9046336482001531

# %%
#pd.DataFrame({'A' : []})

dist_summary = pd.DataFrame({"% Passing Math": pct_pass_math, "% Passing Reading": pct_pass_read, "% Overall Passing":overall_pass,
                             'Total Schools': [total_schools], 'Total Students': [total_students],
                             'Total Budget': [total_budget],"Average Math Score":average_math_score, "Average Reading Score": average_reading_score,})

dist_summary = dist_summary[['Total Schools','Total Students','Total Budget','Average Math Score','Average Reading Score',
                       '% Passing Math','% Passing Reading','% Overall Passing']]
dist_summary
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           32715      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784        0.847281           0.961986           0.904634

# %%
#create school list
school_list = merge_data["School Name"].unique()

# %%
school_summary = merge_data.drop_duplicates(subset="School Name")
school_summary.head()
# Out:
#        School ID            School Name      type  size   budget  Student ID  \
# 0              0      Huang High School  District  2917  1910635           0
# 2917           1   Figueroa High School  District  2949  1884411        2917
# 5866           2    Shelton High School   Charter  1761  1056600        5866
# 7627           3  Hernandez High School  District  4635  3022020        7627
# 12262          4    Griffin High School   Charter  1468   917500       12262
#
#            Student Name gender grade  reading_score  math_score
# 0          Paul Bradley      M   9th             66          79
# 2917         Amy Jacobs      F  10th             85          87
# 5866   Jamie Montgomery      F  12th             70          91
# 7627      Russell Davis      M  10th             70          88
# 12262    Heather Wright      F  11th             79          68

# %%
school_summary = school_summary[["School Name", "type", "size", "budget"]]
school_summary.head()
# Out:
#                  School Name      type  size   budget
# 0          Huang High School  District  2917  1910635
# 2917    Figueroa High School  District  2949  1884411
# 5866     Shelton High School   Charter  1761  1056600
# 7627   Hernandez High School  District  4635  3022020
# 12262    Griffin High School   Charter  1468   917500

# %%
school_summary.set_index("School Name")
# Out:
#                            type  size   budget
# School Name
# Huang High School      District  2917  1910635
# Figueroa High School   District  2949  1884411
# Shelton High School     Charter  1761  1056600
# Hernandez High School  District  4635  3022020
# Griffin High School     Charter  1468   917500
# Wilson High School      Charter  2283  1319574
# Cabrera High School     Charter  1858  1081356
# Bailey High School     District  4976  3124928
# Holden High School      Charter   427   248087
# Pena High School        Charter   962   585858
# Wright High School      Charter  1800  1049400
# Rodriguez High School  District  3999  2547363
# Johnson High School    District  4761  3094650
# Ford High School       District  2739  1763916
# Thomas High School      Charter  1635  1043130

# %%
school_summary["Per Student Budget"] = school_summary["budget"] / school_summary["size"]

for school in school_list:
#    df['total'] = df[['A','B']].sum(axis=1).where(df['A'] > 0, 0)
    #school_summary["Average Math Score"] = merge_data[['math_score']].mean(axis=1).where(merge_data["School Name"]==school)  
    temp = merge_data.loc[merge_data["School Name"] == school,:]
    school_summary.loc[school, ["Average Math Score"]] = temp["math_score"].sum() / len(temp["Student Name"])
    
school_summary
# Out:
#                                  School Name      type    size     budget  \
# 0                          Huang High School  District  2917.0  1910635.0
# 2917                    Figueroa High School  District  2949.0  1884411.0
# 5866                     Shelton High School   Charter  1761.0  1056600.0
# 7627                   Hernandez High School  District  4635.0  3022020.0
# 12262                    Griffin High School   Charter  1468.0   917500.0
# 13730                     Wilson High School   Charter  2283.0  1319574.0
# 16013                    Cabrera High School   Charter  1858.0  1081356.0
# 17871                     Bailey High School  District  4976.0  3124928.0
# 22847                     Holden High School   Charter   427.0   248087.0
# 23274                       Pena High School   Charter   962.0   585858.0
# 24236                     Wright High School   Charter  1800.0  1049400.0
# 26036                  Rodriguez High School  District  3999.0  2547363.0
# 30035                    Johnson High School  District  4761.0  3094650.0
# 34796                       Ford High School  District  2739.0  1763916.0
# 37535                     Thomas High School   Charter  1635.0  1043130.0
# Huang High School                        NaN       NaN     NaN        NaN
# Figueroa High School                     NaN       NaN     NaN        NaN
# Shelton High School                      NaN       NaN     NaN        NaN
# Hernandez High School                    NaN       NaN     NaN        NaN
# Griffin High School                      NaN       NaN     NaN        NaN
# Wilson High School                       NaN       NaN     NaN        NaN
# Cabrera High School                      NaN       NaN     NaN        NaN
# Bailey High School                       NaN       NaN     NaN        NaN
# Holden High School                       NaN       NaN     NaN        NaN
# Pena High School                         NaN       NaN     NaN        NaN
# Wright High School                       NaN       NaN     NaN        NaN
# Rodriguez High School                    NaN       NaN     NaN        NaN
# Johnson High School                      NaN       NaN     NaN        NaN
# Ford High School                         NaN       NaN     NaN        NaN
# Thomas High School                       NaN       NaN     NaN        NaN
#
#                        Per Student Budget  Average Math Score
# 0                                   655.0                 NaN
# 2917                                639.0                 NaN
# 5866                                600.0                 NaN
# 7627                                652.0                 NaN
# 12262                               625.0                 NaN
# 13730                               578.0                 NaN
# 16013                               582.0                 NaN
# 17871                               628.0                 NaN
# 22847                               581.0                 NaN
# 23274                               609.0                 NaN
# 24236                               583.0                 NaN
# 26036                               637.0                 NaN
# 30035                               650.0                 NaN
# 34796                               644.0                 NaN
# 37535                               638.0           76.000000
# Huang High School                     NaN           76.629414
# Figueroa High School                  NaN           76.711767
# Shelton High School                   NaN           83.359455
# Hernandez High School                 NaN           77.289752
# Griffin High School                   NaN           83.351499
# Wilson High School                    NaN           83.274201
# Cabrera High School                   NaN           83.061895
# Bailey High School                    NaN           77.048432
# Holden High School                    NaN           83.803279
# Pena High School                      NaN           83.839917
# Wright High School                    NaN           83.682222
# Rodriguez High School                 NaN           76.842711
# Johnson High School                   NaN           77.072464
# Ford High School                      NaN           77.102592
# Thomas High School                    NaN           83.418349
